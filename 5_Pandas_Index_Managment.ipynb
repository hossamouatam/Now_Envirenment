# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt


#loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()


#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# 3                       San Antonio, TX   via Diversity.com         Full-time
# 4                        Washington, DC  via Clearance Jobs         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# 2                       False               Germany 2023-10-10 13:14:55
# 3                       False  Texas, United States 2023-07-04 13:01:41
# 4                       False                 Sudan 2023-08-07 14:29:36
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 1                          False                 False         Mexico
# 2                          False                 False        Germany
# 3                           True                 False  United States
# 4                          False                 False          Sudan
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
#
#                            company_name  \
# job_index
# 0                  Boehringer Ingelheim
# 1            Hewlett Packard Enterprise
# 2              ALPHA Augmented Services
# 3          Southwest Research Institute
# 4                       Kristina Daniel
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df_GM = df[df['job_country'] == 'Germany']

# %%
df_GM.reset_index(inplace=True)
df_GM
# Out:
#        job_index        job_title_short  \
# 0              2          Data Engineer
# 1             34           Data Analyst
# 2             64    Senior Data Analyst
# 3             78  Senior Data Scientist
# 4            104      Software Engineer
# ...          ...                    ...
# 27689     785728  Senior Data Scientist
# 27690     785729          Data Engineer
# 27691     785732          Data Engineer
# 27692     785735   Senior Data Engineer
# 27693     785737           Data Analyst
#
#                                                job_title        job_location  \
# 0      Data Engineer/Scientist/Analyst, Mid or Senior...     Berlin, Germany
# 1      Data Analyst als Marketing Manager Automation ...   Erlangen, Germany
# 2                                    Senior Data Analyst     Berlin, Germany
# 3                                     Senior Data Expert     Berlin, Germany
# 4                    Senior Software Engineer - Metadata     Berlin, Germany
# ...                                                  ...                 ...
# 27689         Senior Data Scientist, Operations Research              Jerman
# 27690               Data Engineer Marketing Intelligence              Jerman
# 27691                              Data Engineer (f/m/d)  Heidelberg, Jerman
# 27692                               Senior Data Engineer      Berlin, Jerman
# 27693                                   CRM Data Analyst  Bad Rodach, Jerman
#
#                                job_via job_schedule_type  job_work_from_home  \
# 0                         via LinkedIn         Full-time               False
# 1      via Central Illinois Proud Jobs         Full-time               False
# 2                            via BeBee         Full-time               False
# 3                 via Jobs Trabajo.org         Full-time               False
# 4                via Snowflake Careers         Full-time               False
# ...                                ...               ...                 ...
# 27689        melalui BeBee Deutschland   Pekerjaan tetap               False
# 27690        melalui BeBee Deutschland   Pekerjaan tetap               False
# 27691       melalui Top County Careers   Pekerjaan tetap               False
# 27692       melalui Top County Careers   Pekerjaan tetap               False
# 27693        melalui BeBee Deutschland   Pekerjaan tetap               False
#
#       search_location     job_posted_date  job_no_degree_mention  \
# 0             Germany 2023-10-10 13:14:55                  False
# 1             Germany 2023-02-23 13:31:28                   True
# 2             Germany 2023-11-25 13:13:39                   True
# 3             Germany 2023-10-27 13:13:25                  False
# 4             Germany 2023-10-27 13:13:54                  False
# ...               ...                 ...                    ...
# 27689         Germany 2023-03-12 06:18:18                  False
# 27690         Germany 2023-03-12 06:18:18                  False
# 27691         Germany 2023-03-13 06:18:59                  False
# 27692         Germany 2023-03-13 06:19:07                  False
# 27693         Germany 2023-03-12 06:18:18                  False
#
#        job_health_insurance job_country salary_rate  salary_year_avg  \
# 0                     False     Germany        None              NaN
# 1                     False     Germany        None              NaN
# 2                     False     Germany        None              NaN
# 3                     False     Germany        None              NaN
# 4                     False     Germany        None              NaN
# ...                     ...         ...         ...              ...
# 27689                 False     Germany        None              NaN
# 27690                 False     Germany        None              NaN
# 27691                 False     Germany        None              NaN
# 27692                 False     Germany        None              NaN
# 27693                 False     Germany        None              NaN
#
#        salary_hour_avg                  company_name  \
# 0                  NaN      ALPHA Augmented Services
# 1                  NaN                  DEFACTO GmbH
# 2                  NaN                Stepstone GmbH
# 3                  NaN                  SIXT Germany
# 4                  NaN                     Snowflake
# ...                ...                           ...
# 27689              NaN                       Wolt Oy
# 27690              NaN  IU Internationale Hochschule
# 27691              NaN          Heidelberg Materials
# 27692              NaN                      Pure App
# 27693              NaN              HABA FAMILYGROUP
#
#                                               job_skills  \
# 0      ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 1                                                ['sap']
# 2                                                   None
# 3                      ['sql', 'excel', 'looker', 'sap']
# 4                           ['c++', 'java', 'snowflake']
# ...                                                  ...
# 27689                                  ['python', 'sql']
# 27690                                               None
# 27691  ['python', 'c#', 'java', 'scala', 'sql', 'post...
# 27692  ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 27693                     ['sas', 'sas', 'sql', 'excel']
#
#                                          job_type_skills
# 0      {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 1                             {'analyst_tools': ['sap']}
# 2                                                   None
# 3      {'analyst_tools': ['excel', 'looker', 'sap'], ...
# 4      {'cloud': ['snowflake'], 'programming': ['c++'...
# ...                                                  ...
# 27689                 {'programming': ['python', 'sql']}
# 27690                                               None
# 27691  {'cloud': ['azure', 'databricks'], 'databases'...
# 27692  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 27693  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [27694 rows x 18 columns]

# %%
df_GM.set_index('job_index', inplace=True)
df_GM
# Out:
#                  job_title_short  \
# job_index
# 2                  Data Engineer
# 34                  Data Analyst
# 64           Senior Data Analyst
# 78         Senior Data Scientist
# 104            Software Engineer
# ...                          ...
# 785728     Senior Data Scientist
# 785729             Data Engineer
# 785732             Data Engineer
# 785735      Senior Data Engineer
# 785737              Data Analyst
#
#                                                    job_title  \
# job_index
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 34         Data Analyst als Marketing Manager Automation ...
# 64                                       Senior Data Analyst
# 78                                        Senior Data Expert
# 104                      Senior Software Engineer - Metadata
# ...                                                      ...
# 785728            Senior Data Scientist, Operations Research
# 785729                  Data Engineer Marketing Intelligence
# 785732                                 Data Engineer (f/m/d)
# 785735                                  Senior Data Engineer
# 785737                                      CRM Data Analyst
#
#                  job_location                          job_via  \
# job_index
# 2             Berlin, Germany                     via LinkedIn
# 34          Erlangen, Germany  via Central Illinois Proud Jobs
# 64            Berlin, Germany                        via BeBee
# 78            Berlin, Germany             via Jobs Trabajo.org
# 104           Berlin, Germany            via Snowflake Careers
# ...                       ...                              ...
# 785728                 Jerman        melalui BeBee Deutschland
# 785729                 Jerman        melalui BeBee Deutschland
# 785732     Heidelberg, Jerman       melalui Top County Careers
# 785735         Berlin, Jerman       melalui Top County Careers
# 785737     Bad Rodach, Jerman        melalui BeBee Deutschland
#
#           job_schedule_type  job_work_from_home search_location  \
# job_index
# 2                 Full-time               False         Germany
# 34                Full-time               False         Germany
# 64                Full-time               False         Germany
# 78                Full-time               False         Germany
# 104               Full-time               False         Germany
# ...                     ...                 ...             ...
# 785728      Pekerjaan tetap               False         Germany
# 785729      Pekerjaan tetap               False         Germany
# 785732      Pekerjaan tetap               False         Germany
# 785735      Pekerjaan tetap               False         Germany
# 785737      Pekerjaan tetap               False         Germany
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# job_index
# 2         2023-10-10 13:14:55                  False                 False
# 34        2023-02-23 13:31:28                   True                 False
# 64        2023-11-25 13:13:39                   True                 False
# 78        2023-10-27 13:13:25                  False                 False
# 104       2023-10-27 13:13:54                  False                 False
# ...                       ...                    ...                   ...
# 785728    2023-03-12 06:18:18                  False                 False
# 785729    2023-03-12 06:18:18                  False                 False
# 785732    2023-03-13 06:18:59                  False                 False
# 785735    2023-03-13 06:19:07                  False                 False
# 785737    2023-03-12 06:18:18                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 2             Germany        None              NaN              NaN
# 34            Germany        None              NaN              NaN
# 64            Germany        None              NaN              NaN
# 78            Germany        None              NaN              NaN
# 104           Germany        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785728        Germany        None              NaN              NaN
# 785729        Germany        None              NaN              NaN
# 785732        Germany        None              NaN              NaN
# 785735        Germany        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
#
#                            company_name  \
# job_index
# 2              ALPHA Augmented Services
# 34                         DEFACTO GmbH
# 64                       Stepstone GmbH
# 78                         SIXT Germany
# 104                           Snowflake
# ...                                 ...
# 785728                          Wolt Oy
# 785729     IU Internationale Hochschule
# 785732             Heidelberg Materials
# 785735                         Pure App
# 785737                 HABA FAMILYGROUP
#
#                                                   job_skills  \
# job_index
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 34                                                   ['sap']
# 64                                                      None
# 78                         ['sql', 'excel', 'looker', 'sap']
# 104                             ['c++', 'java', 'snowflake']
# ...                                                      ...
# 785728                                     ['python', 'sql']
# 785729                                                  None
# 785732     ['python', 'c#', 'java', 'scala', 'sql', 'post...
# 785735     ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 785737                        ['sas', 'sas', 'sql', 'excel']
#
#                                              job_type_skills
# job_index
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 34                                {'analyst_tools': ['sap']}
# 64                                                      None
# 78         {'analyst_tools': ['excel', 'looker', 'sap'], ...
# 104        {'cloud': ['snowflake'], 'programming': ['c++'...
# ...                                                      ...
# 785728                    {'programming': ['python', 'sql']}
# 785729                                                  None
# 785732     {'cloud': ['azure', 'databricks'], 'databases'...
# 785735     {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 785737     {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [27694 rows x 17 columns]

# %%
median_pivot = df_GM.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median', 'max', 'min'])
median_pivot
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  89100.0        126000.0         29900.0
# Cloud Engineer                    89100.0        200000.0         80850.0
# Data Analyst                     103750.0        200000.0         51014.0
# Data Engineer                    147500.0        200000.0         56700.0
# Data Scientist                   131560.0        192000.0         56700.0
# Machine Learning Engineer         89100.0        224500.0         44418.5
# Senior Data Analyst              111175.0        119400.0         57600.0
# Senior Data Engineer             147500.0        155500.0         72900.0
# Senior Data Scientist            157500.0        224500.0         80850.0
# Software Engineer                 84975.0        177283.0         56700.0

# %%
median_pivot.sort_values(by=('median', 'salary_year_avg'),ascending=False)
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            157500.0        224500.0         80850.0
# Data Engineer                    147500.0        200000.0         56700.0
# Senior Data Engineer             147500.0        155500.0         72900.0
# Data Scientist                   131560.0        192000.0         56700.0
# Senior Data Analyst              111175.0        119400.0         57600.0
# Data Analyst                     103750.0        200000.0         51014.0
# Cloud Engineer                    89100.0        200000.0         80850.0
# Business Analyst                  89100.0        126000.0         29900.0
# Machine Learning Engineer         89100.0        224500.0         44418.5
# Software Engineer                 84975.0        177283.0         56700.0

# %%
median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  89100.0        126000.0         29900.0
# Cloud Engineer                    89100.0        200000.0         80850.0
# Data Analyst                     103750.0        200000.0         51014.0
# Data Engineer                    147500.0        200000.0         56700.0
# Data Scientist                   131560.0        192000.0         56700.0
# Machine Learning Engineer         89100.0        224500.0         44418.5
# Senior Data Analyst              111175.0        119400.0         57600.0
# Senior Data Engineer             147500.0        155500.0         72900.0
# Senior Data Scientist            157500.0        224500.0         80850.0
# Software Engineer                 84975.0        177283.0         56700.0
