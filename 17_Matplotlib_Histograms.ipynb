# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast 


#loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()


#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_GM = df[(df['job_title_short']== 'Data Analyst') & (df['search_location'] == 'Germany')].copy()
df_DA_GM
# Out:
#        job_title_short                                          job_title  \
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# 141       Data Analyst           Data Analyst & Process Developer (m/w/d)
# 142       Data Analyst                               Data Analyst (m/f/d)
# 175       Data Analyst                       German speaking Data Analyst
# 220       Data Analyst                        Inhouse Junior Data Analyst
# ...                ...                                                ...
# 785168    Data Analyst               Data Analyst COO Business Management
# 785176    Data Analyst                               Data Analyst (m/w/d)
# 785357    Data Analyst                               Data Analyst (m/w/d)
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                job_location                          job_via  \
# ...

# %%
df_DA_GM['salary_year_avg'].plot(kind='hist', bins=30, edgecolor='black')
plt.xlim(0, 160000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}K'))

plt.title('Distribution of Germany States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()
